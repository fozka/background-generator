# %%
print('GO')
print('DO')
# Out:
# GO
# DO

# %%
print(2)
# Out:
# 2

# %%
digits = '23'
print(digits[0])
# Out:
# 2

# %%
res = []
letters = [[], [], ['abc'], ['def'], ['ghi'], ['jkl'], ['mno'], ['pqrs'], ['tuv'], ['wxyz']]
for i in range(len(digits)-1):
    for j in range(2):
        print(j)
        print(letters[int(digits[i])][j])
        curr = letters[int(digits[i])][j]
        for k in range(2):
            print(letters[int(digits[i])][k])
            print(k)
#             curr = curr + letters[int(digits[i+1])][k]
#             res.insert(0, curr)

print(res)
# return res
# Out:
# 0
# abc
# abc
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10868/3276839167.py in <module>
#       7         curr = letters[int(digits[i])][j]
#       8         for k in range(2):
# ----> 9             print(letters[int(digits[i])][k])
#      10             print(k)
#      11 #             curr = curr + letters[int(digits[i+1])][k]
#
# IndexError: list index out of range
